# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("datasets/dataset_Facebook.csv")
data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour
# 0              139441   Photo         2          12             4          3  \
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
data.dropna()
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour
# 0              139441   Photo         2          12             4          3  \
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 494             85093   Photo         3           1             7         10
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
#
# ...

# %%
data["Type"].unique()
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %%
photos=data[data["Type"]=="Photo"]
status=data[data["Type"]=="Status"]
videos=data[data["Type"]=="Video"]
links=data[data["Type"]=="Link"]

# %%
merged_data=pd.concat([photos,status])
merged_data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour
# 0              139441   Photo         2          12             4          3  \
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 6              139441   Photo         3          12             1          3
# ..                ...     ...       ...         ...           ...        ...
# 334            119198  Status         2           5             1          2
# 352            116435  Status         1           5             4          3
# 362            116091  Status         2           5             5          7
# 371            113028  Status         2           4             6          3
# 416            104070  Status         1           3             3         15
#
# ...

# %%
data.sort_values(by='Page total likes',ascending=False)
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour
# 0              139441   Photo         2          12             4          3  \
# 8              139441  Status         2          12             7          3
# 1              139441  Status         2          12             3         10
# 12             139441   Photo         2          12             5         10
# 11             139441   Photo         2          12             5         10
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
likes=pd.melt(data,id_vars=["Type","Total Interactions"],value_vars=["Page total likes"],var_name="likes")
likes
# Out:
#        Type  Total Interactions             likes   value
# 0     Photo                 100  Page total likes  139441
# 1    Status                 164  Page total likes  139441
# 2     Photo                  80  Page total likes  139441
# 3     Photo                1777  Page total likes  139441
# 4     Photo                 393  Page total likes  139441
# ..      ...                 ...               ...     ...
# 495   Photo                  84  Page total likes   85093
# 496   Photo                  75  Page total likes   81370
# 497   Photo                 115  Page total likes   81370
# 498   Photo                 136  Page total likes   81370
# 499   Photo                 119  Page total likes   81370
#
# [500 rows x 4 columns]

# %%
interactions=pd.melt(data,id_vars=["Type","Page total likes"],value_vars=["Total Interactions","like"],var_name="interactions")
interactions
# Out:
#        Type  Page total likes        interactions   value
# 0     Photo            139441  Total Interactions   100.0
# 1    Status            139441  Total Interactions   164.0
# 2     Photo            139441  Total Interactions    80.0
# 3     Photo            139441  Total Interactions  1777.0
# 4     Photo            139441  Total Interactions   393.0
# ..      ...               ...                 ...     ...
# 995   Photo             85093                like    53.0
# 996   Photo             81370                like    53.0
# 997   Photo             81370                like    93.0
# 998   Photo             81370                like    91.0
# 999   Photo             81370                like    91.0
#
# [1000 rows x 4 columns]

# %%
data["index"]=range(1,len(data)+1)
cast_wide=pd.pivot_table(data,index=['index'],columns=['Type'],values='Page total likes')
cast_wide=cast_wide.fillna(0)
cast_wide
# Out:
# Type   Link     Photo    Status  Video
# index
# 1       0.0  139441.0       0.0    0.0
# 2       0.0       0.0  139441.0    0.0
# 3       0.0  139441.0       0.0    0.0
# 4       0.0  139441.0       0.0    0.0
# 5       0.0  139441.0       0.0    0.0
# ...     ...       ...       ...    ...
# 496     0.0   85093.0       0.0    0.0
# 497     0.0   81370.0       0.0    0.0
# 498     0.0   81370.0       0.0    0.0
# 499     0.0   81370.0       0.0    0.0
# 500     0.0   81370.0       0.0    0.0
#
# [500 rows x 4 columns]

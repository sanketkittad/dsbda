# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("datasets/Cleavland.csv")
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak
# 0     63    1   1       145   233    1        2      150      0      2.3  \
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope ca thal  num
# 0        3  0    6    0
# 1        2  3    3    2
# ...

# %%
(data=='?').sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# num         0
# dtype: int64

# %%
data.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca           object
# thal         object
# num           int64
# dtype: object

# %%
mode_ca=data["ca"].mode()[0]

data["ca"]=data["ca"].replace("?",mode_ca)
data["ca"]=data["ca"].astype(int)

# %%
mode_ca=data["thal"].mode()[0]

data["thal"]=data["thal"].replace("?",mode_ca)
data["thal"]=data["thal"].astype(int)

# %%
(data<0).sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
plt.hist(data["age"])
# Out:
# (array([ 1., 10., 33., 38., 37., 60., 64., 43., 14.,  3.]),
#  array([29. , 33.8, 38.6, 43.4, 48.2, 53. , 57.8, 62.6, 67.4, 72.2, 77. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(data["num"],data["age"],'go')

# %%
sizes=data["age"].value_counts()
plt.bar(sizes.index,sizes.values)
# Out:
# <BarContainer object of 41 artists>

# %%
sns.lineplot(data["chol"])
# Out:
# <Axes: ylabel='chol'>

# %%
plt.scatter(data["age"],data["chol"],c=data["num"])
plt.plot()
# Out:
# []

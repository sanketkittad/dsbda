# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("datasets/movies_metadata.csv")
data=data.drop(["belongs_to_collection","homepage","genres","spoken_languages","poster_path"],axis='columns')
data
# Out:
# C:\Users\Sanket Kittad\AppData\Local\Temp\ipykernel_16412\2705082601.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv("datasets/movies_metadata.csv")
#        adult    budget      id    imdb_id original_language
# 0      False  30000000     862  tt0114709                en  \
# 1      False  65000000    8844  tt0113497                en
# 2      False         0   15602  tt0113228                en
# 3      False  16000000   31357  tt0114885                en
# 4      False         0   11862  tt0113041                en
# ...      ...       ...     ...        ...               ...
# 45461  False         0  439050  tt6209470                fa
# 45462  False         0  111109  tt2028550                tl
# 45463  False         0   67758  tt0303758                en
# 45464  False         0  227506  tt0008536                en
# 45465  False         0  461257  tt6980792                en
#
# ...

# %%
data["original_language"].unique()
# Out:
# array(['en', 'fr', 'zh', 'it', 'fa', 'nl', 'de', 'cn', 'ar', 'es', 'ru',
#        'sv', 'ja', 'ko', 'sr', 'bn', 'he', 'pt', 'wo', 'ro', 'hu', 'cy',
#        'vi', 'cs', 'da', 'no', 'nb', 'pl', 'el', 'sh', 'xx', 'mk', 'bo',
#        'ca', 'fi', 'th', 'sk', 'bs', 'hi', 'tr', 'is', 'ps', 'ab', 'eo',
#        'ka', 'mn', 'bm', 'zu', 'uk', 'af', 'la', 'et', 'ku', 'fy', 'lv',
#        'ta', 'sl', 'tl', 'ur', 'rw', 'id', 'bg', 'mr', 'lt', 'kk', 'ms',
#        'sq', nan, '104.0', 'qu', 'te', 'am', 'jv', 'tg', 'ml', 'hr', 'lo',
#        'ay', 'kn', 'eu', 'ne', 'pa', 'ky', 'gl', '68.0', 'uz', 'sm', 'mt',
#        '82.0', 'hy', 'iu', 'lb', 'si'], dtype=object)

# %%
data.dropna()
# Out:
#        adult    budget      id    imdb_id original_language
# 1      False  65000000    8844  tt0113497                en  \
# 2      False         0   15602  tt0113228                en
# 3      False  16000000   31357  tt0114885                en
# 4      False         0   11862  tt0113041                en
# 5      False  60000000     949  tt0113277                en
# ...      ...       ...     ...        ...               ...
# 45449  False         0   14885  tt0457437                en
# 45454  False         0  420346  tt4130180                en
# 45456  False         0   84419  tt0038621                en
# 45458  False         0  289923  tt0252966                en
# 45463  False         0   67758  tt0303758                en
#
#                          original_title
# 1                               Jumanji  \
# 2                      Grumpier Old Men
# 3                     Waiting to Exhale
# 4           Father of the Bride Part II
# ...

# %%
data["original_language"].unique()
# Out:
# array(['en', 'fr', 'zh', 'it', 'fa', 'nl', 'de', 'cn', 'ar', 'es', 'ru',
#        'sv', 'ja', 'ko', 'sr', 'bn', 'he', 'pt', 'wo', 'ro', 'hu', 'cy',
#        'vi', 'cs', 'da', 'no', 'nb', 'pl', 'el', 'sh', 'xx', 'mk', 'bo',
#        'ca', 'fi', 'th', 'sk', 'bs', 'hi', 'tr', 'is', 'ps', 'ab', 'eo',
#        'ka', 'mn', 'bm', 'zu', 'uk', 'af', 'la', 'et', 'ku', 'fy', 'lv',
#        'ta', 'sl', 'tl', 'ur', 'rw', 'id', 'bg', 'mr', 'lt', 'kk', 'ms',
#        'sq', nan, '104.0', 'qu', 'te', 'am', 'jv', 'tg', 'ml', 'hr', 'lo',
#        'ay', 'kn', 'eu', 'ne', 'pa', 'ky', 'gl', '68.0', 'uz', 'sm', 'mt',
#        '82.0', 'hy', 'iu', 'lb', 'si'], dtype=object)

# %%
en=data[data["original_language"]=='en']
fr=data[data["original_language"]=='fr']
en
# Out:
#        adult    budget      id    imdb_id original_language
# 0      False  30000000     862  tt0114709                en  \
# 1      False  65000000    8844  tt0113497                en
# 2      False         0   15602  tt0113228                en
# 3      False  16000000   31357  tt0114885                en
# 4      False         0   11862  tt0113041                en
# ...      ...       ...     ...        ...               ...
# 45459  False         0  222848  tt0112613                en
# 45460  False         0   30840  tt0102797                en
# 45463  False         0   67758  tt0303758                en
# 45464  False         0  227506  tt0008536                en
# 45465  False         0  461257  tt6980792                en
#
#                     original_title
# 0                        Toy Story  \
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...

# %%
fr
# Out:
#        adult    budget      id    imdb_id original_language
# 28     False  18000000     902  tt0112682                fr  \
# 32     False         0   78802  tt0114952                fr
# 58     False         0   99040  tt0112714                fr
# 67     False         0    4482  tt0113149                fr
# 72     False         0   48750  tt0113828                fr
# ...      ...       ...     ...        ...               ...
# 45444  False         0   44333  tt0135179                fr
# 45447  False         0   44324  tt0135631                fr
# 45448  False         0  122036  tt0224286                fr
# 45450  False         0   49280  tt0135453                fr
# 45451  False         0  106807  tt0135571                fr
#
#                           original_title
# 28            La Cité des Enfants Perdus  \
# 32      Guillaumet, les ailes du courage
# 58                      Le confessionnal
# 67                          Gazon maudit
# ...

# %%
merged_data=pd.concat([en,fr])
merged_data
# Out:
#        adult    budget      id    imdb_id original_language
# 0      False  30000000     862  tt0114709                en  \
# 1      False  65000000    8844  tt0113497                en
# 2      False         0   15602  tt0113228                en
# 3      False  16000000   31357  tt0114885                en
# 4      False         0   11862  tt0113041                en
# ...      ...       ...     ...        ...               ...
# 45444  False         0   44333  tt0135179                fr
# 45447  False         0   44324  tt0135631                fr
# 45448  False         0  122036  tt0224286                fr
# 45450  False         0   49280  tt0135453                fr
# 45451  False         0  106807  tt0135571                fr
#
#                           original_title
# 0                              Toy Story  \
# 1                                Jumanji
# 2                       Grumpier Old Men
# 3                      Waiting to Exhale
# ...

# %%
data
# Out:
#        adult    budget      id    imdb_id original_language
# 0      False  30000000     862  tt0114709                en  \
# 1      False  65000000    8844  tt0113497                en
# 2      False         0   15602  tt0113228                en
# 3      False  16000000   31357  tt0114885                en
# 4      False         0   11862  tt0113041                en
# ...      ...       ...     ...        ...               ...
# 45461  False         0  439050  tt6209470                fa
# 45462  False         0  111109  tt2028550                tl
# 45463  False         0   67758  tt0303758                en
# 45464  False         0  227506  tt0008536                en
# 45465  False         0  461257  tt6980792                en
#
#                     original_title
# 0                        Toy Story  \
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...

# %%
melted_data=data.melt(id_vars=["id","original_title"],value_vars=["revenue","budget"],value_name="money_metrics",var_name="value")
melted_data
# Out:
#            id               original_title    value money_metrics
# 0         862                    Toy Story  revenue   373554033.0
# 1        8844                      Jumanji  revenue   262797249.0
# 2       15602             Grumpier Old Men  revenue           0.0
# 3       31357            Waiting to Exhale  revenue    81452156.0
# 4       11862  Father of the Bride Part II  revenue    76578911.0
# ...       ...                          ...      ...           ...
# 90927  439050                      رگ خواب   budget             0
# 90928  111109          Siglo ng Pagluluwal   budget             0
# 90929   67758                     Betrayal   budget             0
# 90930  227506          Satana likuyushchiy   budget             0
# 90931  461257                     Queerama   budget             0
#
# [90932 rows x 4 columns]

# %%
data["index"]=range(1,len(data)+1)
wide_data=data.pivot_table(index=['index','id','title'],values=["revenue","budget"])
wide_data
# Out:
#                                               budget      revenue
# index id     title
# 1     862    Toy Story                    30000000.0  373554033.0
# 2     8844   Jumanji                      65000000.0  262797249.0
# 3     15602  Grumpier Old Men                    0.0          0.0
# 4     31357  Waiting to Exhale            16000000.0   81452156.0
# 5     11862  Father of the Bride Part II         0.0   76578911.0
# ...                                              ...          ...
# 45462 439050 Subdue                              0.0          0.0
# 45463 111109 Century of Birthing                 0.0          0.0
# 45464 67758  Betrayal                            0.0          0.0
# 45465 227506 Satan Triumphant                    0.0          0.0
# 45466 461257 Queerama                            0.0          0.0
#
# [45460 rows x 2 columns]

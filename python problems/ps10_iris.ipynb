# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("datasets/Iris.csv")
data
# Out:
#      sepal_length  sepal_width  petal _length  petal_width           class
# 0             5.1          3.5            1.4          0.2     Iris-setosa
# 1             4.9          3.0            1.4          0.2     Iris-setosa
# 2             4.7          3.2            1.3          0.2     Iris-setosa
# 3             4.6          3.1            1.5          0.2     Iris-setosa
# 4             5.0          3.6            1.4          0.2     Iris-setosa
# ..            ...          ...            ...          ...             ...
# 145           6.7          3.0            5.2          2.3  Iris-virginica
# 146           6.3          2.5            5.0          1.9  Iris-virginica
# 147           6.5          3.0            5.2          2.0  Iris-virginica
# 148           6.2          3.4            5.4          2.3  Iris-virginica
# 149           5.9          3.0            5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal _length  petal_width
# count    150.000000   150.000000     150.000000   150.000000
# mean       5.843333     3.054000       3.758667     1.198667
# std        0.828066     0.433594       1.764420     0.763161
# min        4.300000     2.000000       1.000000     0.100000
# 25%        5.100000     2.800000       1.600000     0.300000
# 50%        5.800000     3.000000       4.350000     1.300000
# 75%        6.400000     3.300000       5.100000     1.800000
# max        7.900000     4.400000       6.900000     2.500000

# %%
data.shape
# Out:
# (150, 5)

# %%
data["class"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
i_setosa=data[data["class"]=="Iris-setosa"]
i_versicolor=data[data["class"]=="Iris-versicolor"]
i_virginica=data[data["class"]=="Iris-virginica"]

# %%
i_setosa
# Out:
#     sepal_length  sepal_width  petal _length  petal_width        class
# 0            5.1          3.5            1.4          0.2  Iris-setosa
# 1            4.9          3.0            1.4          0.2  Iris-setosa
# 2            4.7          3.2            1.3          0.2  Iris-setosa
# 3            4.6          3.1            1.5          0.2  Iris-setosa
# 4            5.0          3.6            1.4          0.2  Iris-setosa
# 5            5.4          3.9            1.7          0.4  Iris-setosa
# 6            4.6          3.4            1.4          0.3  Iris-setosa
# 7            5.0          3.4            1.5          0.2  Iris-setosa
# 8            4.4          2.9            1.4          0.2  Iris-setosa
# 9            4.9          3.1            1.5          0.1  Iris-setosa
# 10           5.4          3.7            1.5          0.2  Iris-setosa
# 11           4.8          3.4            1.6          0.2  Iris-setosa
# ...

# %%
i_versicolor
# Out:
#     sepal_length  sepal_width  petal _length  petal_width            class
# 50           7.0          3.2            4.7          1.4  Iris-versicolor
# 51           6.4          3.2            4.5          1.5  Iris-versicolor
# 52           6.9          3.1            4.9          1.5  Iris-versicolor
# 53           5.5          2.3            4.0          1.3  Iris-versicolor
# 54           6.5          2.8            4.6          1.5  Iris-versicolor
# 55           5.7          2.8            4.5          1.3  Iris-versicolor
# 56           6.3          3.3            4.7          1.6  Iris-versicolor
# 57           4.9          2.4            3.3          1.0  Iris-versicolor
# 58           6.6          2.9            4.6          1.3  Iris-versicolor
# 59           5.2          2.7            3.9          1.4  Iris-versicolor
# 60           5.0          2.0            3.5          1.0  Iris-versicolor
# ...

# %%
i_virginica
# Out:
#      sepal_length  sepal_width  petal _length  petal_width           class
# 100           6.3          3.3            6.0          2.5  Iris-virginica
# 101           5.8          2.7            5.1          1.9  Iris-virginica
# 102           7.1          3.0            5.9          2.1  Iris-virginica
# 103           6.3          2.9            5.6          1.8  Iris-virginica
# 104           6.5          3.0            5.8          2.2  Iris-virginica
# 105           7.6          3.0            6.6          2.1  Iris-virginica
# 106           4.9          2.5            4.5          1.7  Iris-virginica
# 107           7.3          2.9            6.3          1.8  Iris-virginica
# 108           6.7          2.5            5.8          1.8  Iris-virginica
# 109           7.2          3.6            6.1          2.5  Iris-virginica
# 110           6.5          3.2            5.1          2.0  Iris-virginica
# ...

# %%
merged_data=pd.concat([i_virginica,i_versicolor])
merged_data
# Out:
#      sepal_length  sepal_width  petal _length  petal_width            class
# 100           6.3          3.3            6.0          2.5   Iris-virginica
# 101           5.8          2.7            5.1          1.9   Iris-virginica
# 102           7.1          3.0            5.9          2.1   Iris-virginica
# 103           6.3          2.9            5.6          1.8   Iris-virginica
# 104           6.5          3.0            5.8          2.2   Iris-virginica
# ..            ...          ...            ...          ...              ...
# 95            5.7          3.0            4.2          1.2  Iris-versicolor
# 96            5.7          2.9            4.2          1.3  Iris-versicolor
# 97            6.2          2.9            4.3          1.3  Iris-versicolor
# 98            5.1          2.5            3.0          1.1  Iris-versicolor
# 99            5.7          2.8            4.1          1.3  Iris-versicolor
#
# [100 rows x 5 columns]

# %%
sorted_data=data.sort_values(by='petal _length')
sorted_data
# Out:
#      sepal_length  sepal_width  petal _length  petal_width           class
# 22            4.6          3.6            1.0          0.2     Iris-setosa
# 13            4.3          3.0            1.1          0.1     Iris-setosa
# 14            5.8          4.0            1.2          0.2     Iris-setosa
# 35            5.0          3.2            1.2          0.2     Iris-setosa
# 36            5.5          3.5            1.3          0.2     Iris-setosa
# ..            ...          ...            ...          ...             ...
# 131           7.9          3.8            6.4          2.0  Iris-virginica
# 105           7.6          3.0            6.6          2.1  Iris-virginica
# 117           7.7          3.8            6.7          2.2  Iris-virginica
# 122           7.7          2.8            6.7          2.0  Iris-virginica
# 118           7.7          2.6            6.9          2.3  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data_transposed=data.transpose()
data_transposed
# Out:
#                        0            1            2            3
# sepal_length           5.1          4.9          4.7          4.6  \
# sepal_width            3.5          3.0          3.2          3.1
# petal _length          1.4          1.4          1.3          1.5
# petal_width            0.2          0.2          0.2          0.2
# class          Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
#                        4            5            6            7
# sepal_length           5.0          5.4          4.6          5.0  \
# sepal_width            3.6          3.9          3.4          3.4
# petal _length          1.4          1.7          1.4          1.5
# petal_width            0.2          0.4          0.3          0.2
# class          Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
#                        8            9    ...             140             141
# sepal_length           4.4          4.9  ...             6.7             6.9  \
# ...

# %%
data
# Out:
#      sepal_length  sepal_width  petal _length  petal_width           class
# 0             5.1          3.5            1.4          0.2     Iris-setosa
# 1             4.9          3.0            1.4          0.2     Iris-setosa
# 2             4.7          3.2            1.3          0.2     Iris-setosa
# 3             4.6          3.1            1.5          0.2     Iris-setosa
# 4             5.0          3.6            1.4          0.2     Iris-setosa
# ..            ...          ...            ...          ...             ...
# 145           6.7          3.0            5.2          2.3  Iris-virginica
# 146           6.3          2.5            5.0          1.9  Iris-virginica
# 147           6.5          3.0            5.2          2.0  Iris-virginica
# 148           6.2          3.4            5.4          2.3  Iris-virginica
# 149           5.9          3.0            5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data["index"]=range(1,len(data)+1)

# %%
melted_data=data.melt(id_vars=["index","class"],value_vars=["sepal_length","sepal_width","petal _length"],value_name="length_id",var_name="lengths")
melted_data
# Out:
#      index           class        lengths  length_id
# 0        1     Iris-setosa   sepal_length        5.1
# 1        2     Iris-setosa   sepal_length        4.9
# 2        3     Iris-setosa   sepal_length        4.7
# 3        4     Iris-setosa   sepal_length        4.6
# 4        5     Iris-setosa   sepal_length        5.0
# ..     ...             ...            ...        ...
# 445    146  Iris-virginica  petal _length        5.2
# 446    147  Iris-virginica  petal _length        5.0
# 447    148  Iris-virginica  petal _length        5.2
# 448    149  Iris-virginica  petal _length        5.4
# 449    150  Iris-virginica  petal _length        5.1
#
# [450 rows x 4 columns]

# %%
wide_data=data.pivot_table(index="index",values=["petal _length","petal_width","sepal_length","sepal_width"])
wide_data
# Out:
#        petal _length  petal_width  sepal_length  sepal_width
# index
# 1                1.4          0.2           5.1          3.5
# 2                1.4          0.2           4.9          3.0
# 3                1.3          0.2           4.7          3.2
# 4                1.5          0.2           4.6          3.1
# 5                1.4          0.2           5.0          3.6
# ...              ...          ...           ...          ...
# 146              5.2          2.3           6.7          3.0
# 147              5.0          1.9           6.3          2.5
# 148              5.2          2.0           6.5          3.0
# 149              5.4          2.3           6.2          3.4
# 150              5.1          1.8           5.9          3.0
#
# [150 rows x 4 columns]
